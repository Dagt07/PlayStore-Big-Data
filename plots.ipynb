# %%
import pandas as pd

data_1 = pd.read_csv("query_1.csv")
data_1
# Out:
#                    Category  Total_Installs
# 0                     Tools     46440471469
# 1              Productivity     23314050628
# 2             Communication     18216594754
# 3                    Action     17400377388
# 4             Entertainment     17108498394
# 5                    Casual     16837071701
# 6                    Arcade     14501333037
# 7             Music & Audio     14239411974
# 8               Photography     13998958963
# 9                    Social     12165995316
# 10               Simulation     11690020565
# 11                   Puzzle     10796428127
# 12          Personalization      9252977243
# 13                   Racing      9218081047
# 14  Video Players & Editors      8591154209
# 15                   Sports      7954127503
# 16                 Shopping      7108602885
# 17                  Finance      6158488850
# 18                Lifestyle      5997923997
# 19                Education      5983961831
# ...

# %%
data_1_top = data_1.head(10)
data_1_top.plot(kind="bar", x = "Category", y = "Total_Installs")
# Out:
# <Axes: xlabel='Category'>

# %%
data_2 = pd.read_csv("query_2.csv")
data_2
# Out:
#                    Category  Total_Installs
# 0                    Action        55011248
# 1                    Arcade        31009592
# 2                     Tools        26254772
# 3                    Puzzle        25579261
# 4           Personalization        24057260
# 5              Role Playing        22984905
# 6                 Adventure        21264624
# 7                Simulation        19024466
# 8                  Strategy        18330909
# 9             Music & Audio        16542903
# 10              Photography        13971333
# 11             Productivity        13657064
# 12                Education        11435772
# 13              Educational        10217657
# 14                   Sports         9254029
# 15                   Racing         8470541
# 16                   Casual         7710448
# 17            Communication         6984499
# 18         Health & Fitness         5689547
# 19                    Board         5312646
# ...

# %%
data_2_top = data_2.head(10)
data_2_top.plot(kind="bar", x = "Category", y = "Total_Installs")
# Out:
# <Axes: xlabel='Category'>
